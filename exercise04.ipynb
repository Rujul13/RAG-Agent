# %%
# !pip install llama-index -q -q

# %%
# !pip install tavily-python -q -q

# %%
from tavily import AsyncTavilyClient
from llama_index.core.agent.workflow import AgentWorkflow
from llama_index.llms.openai import OpenAI
import os
from openai import OpenAI as OpenAIClient

raw_client = OpenAIClient()

API_KEY   = raw_client.api_key
API_BASE  = raw_client.base_url

tavily_api_key = os.environ["TAVILY_API_KEY"]

async def search_web(query: str) -> str:
    """Useful for using the web to answer questions."""
    client = AsyncTavilyClient(api_key=tavily_api_key)
    return str(await client.search(query))

llm = OpenAI(model="gpt-4o-mini", api_key=API_KEY, api_base=API_BASE)

workflow = AgentWorkflow.from_tools_or_functions(
    [search_web],
    llm=llm,
    system_prompt="You are a helpful assistant that answers questions. If you don't know the answer, you can search the web for information.",
)

# %%
from llama_index.core.agent.workflow import (
    AgentInput,
    AgentOutput,
    ToolCall,
    ToolCallResult,
    AgentStream,
)

handler = workflow.run(user_msg="What is the weather in Saskatoon?")

async for event in handler.stream_events():
    if isinstance(event, AgentStream):
        print(event.delta, end="", flush=True)
# Out:
# The current weather in Saskatoon is as follows:
#
# - **Temperature**: 26.3°C (79.3°F)
# - **Condition**: Sunny
# - **Feels Like**: 27.1°C (80.7°F)
# - **Wind**: 7.6 mph (12.2 kph) from the WSW
# - **Humidity**: 48%
# - **Visibility**: 19 km (11 miles)
# - **Pressure**: 1017.0 mb (30.03 in)
#
# Overall, it's a sunny day with a slight chance of showers later in the afternoon.
#
# For more details, you can check the full weather report [here](https://www.weatherapi.com/).

# %% [markdown]
# turning on more logging and running it again.

# %%
from llama_index.core.agent.workflow import (
    AgentInput,
    AgentOutput,
    ToolCall,
    ToolCallResult,
    AgentStream,
)

handler = workflow.run(user_msg="What is the weather in Saskatoon?")

async for event in handler.stream_events():
    if isinstance(event, AgentInput):
       print("Agent input: ", event.input)  # Current input messages
       print("Agent name:", event.current_agent_name)  # Current agent name
    elif isinstance(event, AgentOutput):
       print("Agent output: ", event.response)  # Current full response
       print("Tool calls made: ", event.tool_calls)  # Selected tool calls, if any
       print("Raw LLM response: ", event.raw)  # Raw llm api response
    elif isinstance(event, ToolCallResult):
       print("Tool called: ", event.tool_name)  # Tool name
       print("Arguments to the tool: ", event.tool_kwargs)  # Tool kwargs
       print("Tool output: ", event.tool_output)  # Tool output
# Out:
# Agent input:  [ChatMessage(role=<MessageRole.SYSTEM: 'system'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text="You are a helpful assistant that answers questions. If you don't know the answer, you can search the web for information.")]), ChatMessage(role=<MessageRole.USER: 'user'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='What is the weather in Saskatoon?')])]
# Agent name: Agent
# Agent output:  assistant:
# Tool calls made:  [ToolSelection(tool_id='call_a0qqgpnO0SdnH5LoNBrAqqX9', tool_name='search_web', tool_kwargs={'query': 'current weather in Saskatoon'})]
# Raw LLM response:  {'id': 'chatcmpl-CAhfD5EhfRxj0h9F3PPlK5JBHRR6N', 'choices': [{'delta': {'content': None, 'function_call': None, 'refusal': None, 'role': None, 'tool_calls': None}, 'finish_reason': 'tool_calls', 'index': 0, 'logprobs': None}], 'created': 1756667159, 'model': 'gpt-4o-mini-2024-07-18', 'object': 'chat.completion.chunk', 'service_tier': 'default', 'system_fingerprint': 'fp_560af6e559', 'usage': None, 'obfuscation': 'QSoO5jR09eyY'}
# Tool called:  search_web
# Arguments to the tool:  {'query': 'current weather in Saskatoon'}
# Tool output:  {'query': 'current weather in Saskatoon', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Weather in Saskatoon', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Saskatoon', 'region': 'Saskatchewan', 'country': 'Canada', 'lat': 52.1333, 'lon': -106.6667, 'tz_id': 'America/Regina', 'localtime_epoch': 1756667310, 'localtime': '2025-08-31 13:08'}, 'current': {'last_updated_epoch': 1756666800, 'last_updated': '2025-08-31 13:00', 'temp_c': 26.3, 'temp_f': 79.3, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 7.6, 'wind_kph': 12.2, 'wind_degree': 241, 'wind_dir': 'WSW', 'pressure_mb': 1017.0, 'pressure_in': 30.03, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 48, 'cloud': 25, 'feelslike_c': 27.1, 'feelslike_f': 80.7, 'windchill_c': 27.4, 'windchill_f': 81.4, 'heatindex_c': 28.6, 'heatindex_f': 83.4, 'dewpoint_c': 17.6, 'dewpoint_f': 63.6, 'vis_km': 19.0, 'vis_miles': 11.0, 'uv': 5.4, 'gust_mph': 8.7, 'gust_kph': 14.1}}", 'score': 0.9678631, 'raw_content': None}, {'url': 'https://www.theweathernetwork.com/en/city/ca/saskatchewan/saskatoon/current', 'title': 'Saskatoon, SK Current Weather', 'content': 'POP. 10%. 1pm. Sunny. 26°. Feels 30. POP. 10%. 2pm. Mainly sunny. 27°. Feels 31. POP. 10%. Detailed Observations. August 31, 2025. Sunrise. 6:17AM. Sunset. 7:', 'score': 0.9356824, 'raw_content': None}, {'url': 'https://www.timeanddate.com/weather/canada/saskatoon', 'title': 'Weather for Saskatoon, Saskatchewan, Canada', 'content': 'Weather in Saskatoon, Saskatchewan, Canada ; Aug 31, 2025 at 3:00 am · 15 mi · 30.04 "Hg · 73% · 55 °F', 'score': 0.91118777, 'raw_content': None}, {'url': 'https://weather.gc.ca/en/location/index.html?coords=52.131,-106.659', 'title': 'Saskatoon, SK - 7 Day Forecast', 'content': 'Detailed ForecastForecast issued: 5:00 AM CST Sunday 31 August 2025 ; Today, A mix of sun and cloud. 30 percent chance of showers late this afternoon with risk', 'score': 0.8872928, 'raw_content': None}, {'url': 'https://weather.gc.ca/past_conditions/index_e.html?station=YXE', 'title': "Saskatoon Diefenbaker Int'l Airport - Past 24 Hour Conditions", 'content': 'Hourly weather conditions summary for the past 24 hours. This includes conditions, temperature ... 31 August 2025. 08:00. Mostly Cloudy. 18 (17.8), 64 (64.0), S', 'score': 0.8805613, 'raw_content': None}], 'response_time': 1.77, 'request_id': '717958df-2cda-490b-b3a7-a766b9b1f21c'}
# Agent input:  [ChatMessage(role=<MessageRole.SYSTEM: 'system'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text="You are a helpful assistant that answers questions. If you don't know the answer, you can search the web for information.")]), ChatMessage(role=<MessageRole.USER: 'user'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='What is the weather in Saskatoon?')]), ChatMessage(role=<MessageRole.ASSISTANT: 'assistant'>, additional_kwargs={'tool_calls': [ChoiceDeltaToolCall(index=0, id='call_a0qqgpnO0SdnH5LoNBrAqqX9', function=ChoiceDeltaToolCallFunction(arguments='{"query":"current weather in Saskatoon"}', name='search_web'), type='function')]}, blocks=[TextBlock(block_type='text', text='')]), ChatMessage(role=<MessageRole.TOOL: 'tool'>, additional_kwargs={'tool_call_id': 'call_a0qqgpnO0SdnH5LoNBrAqqX9'}, blocks=[TextBlock(block_type='text', text='{\'query\': \'current weather in Saskatoon\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Saskatoon\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Saskatoon\', \'region\': \'Saskatchewan\', \'country\': \'Canada\', \'lat\': 52.1333, \'lon\': -106.6667, \'tz_id\': \'America/Regina\', \'localtime_epoch\': 1756667310, \'localtime\': \'2025-08-31 13:08\'}, \'current\': {\'last_updated_epoch\': 1756666800, \'last_updated\': \'2025-08-31 13:00\', \'temp_c\': 26.3, \'temp_f\': 79.3, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 7.6, \'wind_kph\': 12.2, \'wind_degree\': 241, \'wind_dir\': \'WSW\', \'pressure_mb\': 1017.0, \'pressure_in\': 30.03, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 48, \'cloud\': 25, \'feelslike_c\': 27.1, \'feelslike_f\': 80.7, \'windchill_c\': 27.4, \'windchill_f\': 81.4, \'heatindex_c\': 28.6, \'heatindex_f\': 83.4, \'dewpoint_c\': 17.6, \'dewpoint_f\': 63.6, \'vis_km\': 19.0, \'vis_miles\': 11.0, \'uv\': 5.4, \'gust_mph\': 8.7, \'gust_kph\': 14.1}}", \'score\': 0.9678631, \'raw_content\': None}, {\'url\': \'https://www.theweathernetwork.com/en/city/ca/saskatchewan/saskatoon/current\', \'title\': \'Saskatoon, SK Current Weather\', \'content\': \'POP. 10%. 1pm. Sunny. 26°. Feels 30. POP. 10%. 2pm. Mainly sunny. 27°. Feels 31. POP. 10%. Detailed Observations. August 31, 2025. Sunrise. 6:17AM. Sunset. 7:\', \'score\': 0.9356824, \'raw_content\': None}, {\'url\': \'https://www.timeanddate.com/weather/canada/saskatoon\', \'title\': \'Weather for Saskatoon, Saskatchewan, Canada\', \'content\': \'Weather in Saskatoon, Saskatchewan, Canada ; Aug 31, 2025 at 3:00 am · 15 mi · 30.04 "Hg · 73% · 55 °F\', \'score\': 0.91118777, \'raw_content\': None}, {\'url\': \'https://weather.gc.ca/en/location/index.html?coords=52.131,-106.659\', \'title\': \'Saskatoon, SK - 7 Day Forecast\', \'content\': \'Detailed ForecastForecast issued: 5:00 AM CST Sunday 31 August 2025 ; Today, A mix of sun and cloud. 30 percent chance of showers late this afternoon with risk\', \'score\': 0.8872928, \'raw_content\': None}, {\'url\': \'https://weather.gc.ca/past_conditions/index_e.html?station=YXE\', \'title\': "Saskatoon Diefenbaker Int\'l Airport - Past 24 Hour Conditions", \'content\': \'Hourly weather conditions summary for the past 24 hours. This includes conditions, temperature ... 31 August 2025. 08:00. Mostly Cloudy. 18 (17.8), 64 (64.0), S\', \'score\': 0.8805613, \'raw_content\': None}], \'response_time\': 1.77, \'request_id\': \'717958df-2cda-490b-b3a7-a766b9b1f21c\'}')])]
# Agent name: Agent
# Agent output:  assistant: The current weather in Saskatoon is as follows:
#
# - **Temperature**: 26.3°C (feels like 27.1°C)
# - **Condition**: Sunny
# - **Wind**: 7.6 mph (12.2 kph) from the WSW
# - **Humidity**: 48%
# - **Visibility**: 19 km
# - **Pressure**: 1017 mb
#
# For more details, you can check the full weather report [here](https://www.weatherapi.com/).
# Tool calls made:  []
# Raw LLM response:  {'id': 'chatcmpl-CAhfGxpnugzhy5mDNV7pGPnQsgck7', 'choices': [{'delta': {'content': None, 'function_call': None, 'refusal': None, 'role': None, 'tool_calls': None}, 'finish_reason': 'stop', 'index': 0, 'logprobs': None}], 'created': 1756667162, 'model': 'gpt-4o-mini-2024-07-18', 'object': 'chat.completion.chunk', 'service_tier': 'default', 'system_fingerprint': 'fp_560af6e559', 'usage': None, 'obfuscation': 'x1'}

# %% [markdown]
# We can see the agent accepting input, picking the web search tool, calling it with appropriate arguments, and returning the output.
